# %% [markdown]
# ### Group 1040 - Week 3 - Works

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### 1. Loading the data into the pandas dataframe

# %%
gender_age_train_data = pd.read_csv("gender_age_train.csv")
gender_age_train_data.head()
# Out:
#    Unnamed: 0            device_id gender  age age_group
# 0           0 -8076087639492063270      M   35    M32-38
# 1           1 -2897161552818060146      M   35    M32-38
# 2           2 -8260683887967679142      M   35    M32-38
# 3           3 -4938849341048082022      M   30    M29-31
# 4           4   245133531816851882      M   30    M29-31

# %%
phone_brand_device_model_data = pd.read_csv("phone_brand_device_model.csv")
phone_brand_device_model_data.head()
# Out:
#    Unnamed: 0            device_id brand models_phone_brand
# 0           0  1877775838486905855  vivo                Y13
# 1           1 -3766087376657242966    小米               V183
# 2           2 -6238937574958215831  OPPO                R7s
# 3           3  8973197758510677470    三星              A368t
# 4           4 -2015528097870762664    小米            红米Note2

# %%
events_data = pd.read_csv("events_data.csv")
events_data.head()
# Out:
#    event_id     device_id            timestamp  longitude  latitude   city  \
# 0       1.0  2.918269e+16  2016-05-01 00:55:25  77.266049  28.68161  Delhi
# 1    7104.0  2.918269e+16  2016-05-02 09:37:02  77.266049  28.68161  Delhi
# 2   29661.0  2.918269e+16  2016-05-04 00:56:04  77.266049  28.68161  Delhi
# 3   33133.0  2.918269e+16  2016-05-06 05:01:15  77.266049  28.68161  Delhi
# 4   38980.0  2.918269e+16  2016-05-06 09:55:04  77.266049  28.68161  Delhi
#
#    state
# 0  Delhi
# 1  Delhi
# 2  Delhi
# 3  Delhi
# 4  Delhi

# %% [markdown]
# ### 2. Filtering the data based on the State of focus and dropping the unwanted columns

# %%
filtered_events_data = events_data[(events_data.state == "MadhyaPradesh") | 
                                   (events_data.state == "Chhattisgarh") | 
                                   (events_data.state == "Uttaranchal") | 
                                   (events_data.state == "JammuandKashmir") | 
                                   (events_data.state == "Goa") | 
                                   (events_data.state == "Nagaland")
                                  ]
filtered_events_data.head()
# Out:
#          event_id     device_id            timestamp  longitude  latitude  \
# 2197849   10117.0 -5.323073e+18  2016-05-01 11:11:24  75.939543  22.76917
# 2197850  112369.0 -5.323073e+18  2016-05-04 22:47:19  75.939543  22.76917
# 2197851  139098.0 -5.323073e+18  2016-05-01 09:55:58  75.939543  22.76917
# 2197852  190983.0 -5.323073e+18  2016-05-04 22:51:03  75.939543  22.76917
# 2197853  249507.0 -5.323073e+18  2016-05-01 11:24:12  75.939543  22.76917
#
#            city          state
# 2197849  Indore  MadhyaPradesh
# 2197850  Indore  MadhyaPradesh
# 2197851  Indore  MadhyaPradesh
# 2197852  Indore  MadhyaPradesh
# 2197853  Indore  MadhyaPradesh

# %%
gender_age_train_data.drop(labels = "Unnamed: 0", axis = 1, inplace = True)
gender_age_train_data.head()
# Out:
#              device_id gender  age age_group
# 0 -8076087639492063270      M   35    M32-38
# 1 -2897161552818060146      M   35    M32-38
# 2 -8260683887967679142      M   35    M32-38
# 3 -4938849341048082022      M   30    M29-31
# 4   245133531816851882      M   30    M29-31

# %%
phone_brand_device_model_data.drop(labels = "Unnamed: 0", axis = 1, inplace = True)
phone_brand_device_model_data.head()
# Out:
#              device_id brand models_phone_brand
# 0  1877775838486905855  vivo                Y13
# 1 -3766087376657242966    小米               V183
# 2 -6238937574958215831  OPPO                R7s
# 3  8973197758510677470    三星              A368t
# 4 -2015528097870762664    小米            红米Note2

# %% [markdown]
# ### 3. Checking the null values in the data

# %%
filtered_events_data.isnull().sum()
# Out:
# event_id      0
# device_id    51
# timestamp     0
# longitude    63
# latitude     63
# city          0
# state         0
# dtype: int64

# %%
gender_age_train_data.isnull().sum()
# Out:
# device_id    0
# gender       0
# age          0
# age_group    0
# dtype: int64

# %%
phone_brand_device_model_data.isnull().sum()
# Out:
# device_id             0
# brand                 0
# models_phone_brand    0
# dtype: int64

# %% [markdown]
# #### Observation:
#
# 1. gender_age_train_data and phone_brand_device_model_data dataframes does not have any null values
# 2. Events data have null values in below list of columns.
#         - device_id
#         - longitude
#         - latitude

# %% [markdown]
# ### 4. Checking the shape of the data

# %%
filtered_events_data.shape
# Out:
# (261097, 7)

# %%
gender_age_train_data.shape
# Out:
# (74645, 4)

# %%
phone_brand_device_model_data.shape
# Out:
# (87726, 3)

# %% [markdown]
# ### 5. Handling the null values in the data

# %%
device_id_null_values = filtered_events_data[filtered_events_data.device_id.isnull()]
print(device_id_null_values.shape)
device_id_null_values
# Out:
# (51, 7)
#           event_id  device_id            timestamp  longitude   latitude  \
# 2246176    84091.0        NaN  2016-05-02 13:28:09  75.882956  22.814519
# 2246179    93602.0        NaN  2016-05-03 11:57:22  75.882956  22.814519
# 2246247   356056.0        NaN  2016-05-02 13:48:16  75.882956  22.814519
# 2246295   558444.0        NaN  2016-05-02 18:58:23  75.882956  22.814519
# 2246358   850678.0        NaN  2016-05-07 15:40:10  75.882956  22.814519
# 2246388  1037766.0        NaN  2016-05-03 12:00:46  75.882956  22.814519
# 2246435  1228197.0        NaN  2016-05-02 13:32:29  75.882956  22.814519
# 2246458  1350986.0        NaN  2016-05-01 22:11:23  75.882956  22.814519
# 2246476  1376079.0        NaN  2016-05-03 16:14:56  75.882956  22.814519
# 2246528  1603987.0        NaN  2016-05-04 10:57:10  75.882956  22.814519
# 2246550  1672836.0        NaN  2016-05-04 14:55:00  75.882956  22.814519
# 2246595  1848062.0        NaN  2016-05-07 08:20:25  75.882956  22.814519
# 2246617  1936567.0        NaN  2016-05-02 15:27:54  75.882956  22.814519
# 2246704  2267349.0        NaN  2016-05-02 15:29:57  75.882956  22.814519
# 2246768  2477669.0        NaN  2016-05-06 11:17:50  75.882956  22.814519
# 2246797  2611948.0        NaN  2016-05-07 10:53:48  75.882956  22.814519
# 2246905  3096112.0        NaN  2016-05-01 11:41:33  75.882956  22.814519
# 2251261    93979.0        NaN  2016-05-03 11:36:45  75.958050  22.817526
# 2251264   112153.0        NaN  2016-05-04 22:00:38  75.958050  22.817526
# 2251332   469387.0        NaN  2016-05-03 19:28:48  75.958050  22.817526
# 2251380   646659.0        NaN  2016-05-06 21:25:57  75.958050  22.817526
# 2251443   903561.0        NaN  2016-05-07 14:49:22  75.958050  22.817526
# 2251473  1023857.0        NaN  2016-05-06 21:40:35  75.958050  22.817526
# 2251520  1239767.0        NaN  2016-05-06 20:50:05  75.958050  22.817526
# 2251543  1360125.0        NaN  2016-05-04 07:36:34  75.958050  22.817526
# 2251561  1408777.0        NaN  2016-05-06 20:54:44  75.958050  22.817526
# 2251613  1618847.0        NaN  2016-05-05 19:44:46  75.958050  22.817526
# 2251635  1699963.0        NaN  2016-05-06 22:54:36  75.958050  22.817526
# 2251680  1887094.0        NaN  2016-05-06 14:04:00  75.958050  22.817526
# 2251702  1974711.0        NaN  2016-05-04 18:14:08  75.958050  22.817526
# 2251789  2363820.0        NaN  2016-05-02 12:20:15  75.958050  22.817526
# 2251853  2594217.0        NaN  2016-05-03 19:03:43  75.958050  22.817526
# 2251882  2729797.0        NaN  2016-05-04 15:05:36  75.958050  22.817526
# 2251990  3167450.0        NaN  2016-05-03 20:29:43  75.958050  22.817526
# 2312844    53038.0        NaN  2016-05-01 18:11:24  75.923332  22.777781
# 2312847    62725.0        NaN  2016-05-05 23:29:23  75.923332  22.777781
# 2312915   310080.0        NaN  2016-05-02 15:37:17  75.923332  22.777781
# 2312963   520053.0        NaN  2016-05-01 16:23:00  75.923332  22.777781
# 2313026   754221.0        NaN  2016-05-04 20:57:43  75.923332  22.777781
# 2313056   908097.0        NaN  2016-05-04 18:56:54  75.923332  22.777781
# 2313103  1102536.0        NaN  2016-05-06 21:19:09  75.923332  22.777781
# 2313126  1205324.0        NaN  2016-05-02 15:42:14  75.923332  22.777781
# 2313144  1261612.0        NaN  2016-05-04 19:07:05  75.923332  22.777781
# 2313196  1558323.0        NaN  2016-05-01 21:53:01  75.923332  22.777781
# 2313218  1674442.0        NaN  2016-05-06 15:47:24  75.923332  22.777781
# 2313263  1903648.0        NaN  2016-05-02 15:41:54  75.923332  22.777781
# 2313285  1974053.0        NaN  2016-05-01 18:12:07  75.923332  22.777781
# 2313372  2370402.0        NaN  2016-05-01 16:20:07  75.923332  22.777781
# 2313436  2621408.0        NaN  2016-05-04 18:24:57  75.923332  22.777781
# 2313465  2762149.0        NaN  2016-05-07 20:49:42  75.923332  22.777781
# 2313573  3214579.0        NaN  2016-05-05 22:24:32  75.923332  22.777781
#
#            city          state
# 2246176  Indore  MadhyaPradesh
# 2246179  Indore  MadhyaPradesh
# 2246247  Indore  MadhyaPradesh
# 2246295  Indore  MadhyaPradesh
# 2246358  Indore  MadhyaPradesh
# 2246388  Indore  MadhyaPradesh
# 2246435  Indore  MadhyaPradesh
# 2246458  Indore  MadhyaPradesh
# 2246476  Indore  MadhyaPradesh
# 2246528  Indore  MadhyaPradesh
# 2246550  Indore  MadhyaPradesh
# 2246595  Indore  MadhyaPradesh
# 2246617  Indore  MadhyaPradesh
# 2246704  Indore  MadhyaPradesh
# 2246768  Indore  MadhyaPradesh
# 2246797  Indore  MadhyaPradesh
# 2246905  Indore  MadhyaPradesh
# 2251261  Indore  MadhyaPradesh
# 2251264  Indore  MadhyaPradesh
# 2251332  Indore  MadhyaPradesh
# 2251380  Indore  MadhyaPradesh
# 2251443  Indore  MadhyaPradesh
# 2251473  Indore  MadhyaPradesh
# 2251520  Indore  MadhyaPradesh
# 2251543  Indore  MadhyaPradesh
# 2251561  Indore  MadhyaPradesh
# 2251613  Indore  MadhyaPradesh
# 2251635  Indore  MadhyaPradesh
# 2251680  Indore  MadhyaPradesh
# 2251702  Indore  MadhyaPradesh
# 2251789  Indore  MadhyaPradesh
# 2251853  Indore  MadhyaPradesh
# 2251882  Indore  MadhyaPradesh
# 2251990  Indore  MadhyaPradesh
# 2312844  Indore  MadhyaPradesh
# 2312847  Indore  MadhyaPradesh
# 2312915  Indore  MadhyaPradesh
# 2312963  Indore  MadhyaPradesh
# 2313026  Indore  MadhyaPradesh
# 2313056  Indore  MadhyaPradesh
# 2313103  Indore  MadhyaPradesh
# 2313126  Indore  MadhyaPradesh
# 2313144  Indore  MadhyaPradesh
# 2313196  Indore  MadhyaPradesh
# 2313218  Indore  MadhyaPradesh
# 2313263  Indore  MadhyaPradesh
# 2313285  Indore  MadhyaPradesh
# 2313372  Indore  MadhyaPradesh
# 2313436  Indore  MadhyaPradesh
# 2313465  Indore  MadhyaPradesh
# 2313573  Indore  MadhyaPradesh

# %%
latitude_longitude_null_values = filtered_events_data[filtered_events_data.latitude.isnull()]
print(latitude_longitude_null_values.shape)
latitude_longitude_null_values
# Out:
# (63, 7)
#           event_id     device_id            timestamp  longitude  latitude  \
# 2209280    98473.0  2.350979e+18  2016-05-01 13:26:19        NaN       NaN
# 2209338   306267.0  2.350979e+18  2016-05-04 12:28:22        NaN       NaN
# 2209342   325499.0  2.350979e+18  2016-05-03 00:04:38        NaN       NaN
# 2209409   548071.0  2.350979e+18  2016-05-03 10:15:01        NaN       NaN
# 2209447   670642.0  2.350979e+18  2016-05-01 09:39:47        NaN       NaN
# ...            ...           ...                  ...        ...       ...
# 2231730  2338442.0  3.738280e+18  2016-05-03 13:38:44        NaN       NaN
# 2231772  2549252.0  3.738280e+18  2016-05-02 09:44:11        NaN       NaN
# 2231836  2843278.0  3.738280e+18  2016-05-01 01:08:00        NaN       NaN
# 2231892  3066955.0  3.738280e+18  2016-05-01 14:20:10        NaN       NaN
# 2231924  3227166.0  3.738280e+18  2016-05-04 08:47:05        NaN       NaN
#
#            city          state
# 2209280  Indore  MadhyaPradesh
# 2209338  Indore  MadhyaPradesh
# 2209342  Indore  MadhyaPradesh
# 2209409  Indore  MadhyaPradesh
# 2209447  Indore  MadhyaPradesh
# ...         ...            ...
# 2231730  Indore  MadhyaPradesh
# 2231772  Indore  MadhyaPradesh
# 2231836  Indore  MadhyaPradesh
# 2231892  Indore  MadhyaPradesh
# 2231924  Indore  MadhyaPradesh
#
# [63 rows x 7 columns]

# %% [markdown]
# #### Observation:
#
# 1. As null values in the device_id column cannot be replaced with any other device id's we are dropping the records containing device_id columns as null values.
#
# 2. As null values in the latitude and longitude columns belog to the city - Indore and state-Madhyapradesh, we are replacing the latitude and longitude values of city - Indore and state - MadhyaPradesh for the records with null values.

# %% [markdown]
# #### 5.1 Dropping the rows with null values in device_id column

# %%
filtered_events_data.dropna(how = "any", subset = ["device_id"], axis = 0, inplace = True)
# Out:
# C:\Users\vaithy\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
filtered_events_data.device_id.isnull().sum()
# Out:
# 0

# %%
filtered_events_data.shape
# Out:
# (261046, 7)

# %% [markdown]
# #### 5.2 Replacing the null vaues longitude and latitude columns

# %%
latitude_longitude_null_values.device_id.unique()
# Out:
# array([ 2.35097940e+18, -8.79056003e+18,  3.73828049e+18])

# %%
75.888474,22.745063000000002, 2.3509794022024387e+18
75.933778,22.761965, -8.790560034584249e+18
75.937988,22.76201, 3.738280493453803e+18

# %%
filtered_events_data.loc[(filtered_events_data.device_id == 2.3509794022024387e+18), "longitude"] = 75.888474
filtered_events_data.loc[(filtered_events_data.device_id == -8.790560034584249e+18), "longitude"] = 75.933778
filtered_events_data.loc[(filtered_events_data.device_id == 3.738280493453803e+18), "longitude"] = 75.937988

filtered_events_data.loc[(filtered_events_data.device_id == 2.3509794022024387e+18), "latitude"] = 22.745063000000002
filtered_events_data.loc[(filtered_events_data.device_id == -8.790560034584249e+18), "latitude"] = 22.761965
filtered_events_data.loc[(filtered_events_data.device_id == 3.738280493453803e+18), "latitude"] = 22.76201

# %%
#filtered_events_data[(filtered_events_data.device_id == 2.3509794022024387e+18)]["longitude"].unique()
#filtered_events_data[(filtered_events_data.device_id == -8.790560034584249e+18)]["longitude"].unique()
#filtered_events_data[(filtered_events_data.device_id == 3.738280493453803e+18)]["longitude"].unique()

#filtered_events_data[(filtered_events_data.device_id == 2.3509794022024387e+18)]["latitude"].unique()
#filtered_events_data[(filtered_events_data.device_id == -8.790560034584249e+18)]["latitude"].unique()
#filtered_events_data[(filtered_events_data.device_id == 3.738280493453803e+18)]["latitude"].unique()

# %%
filtered_events_data.isnull().sum()
# Out:
# event_id     0
# device_id    0
# timestamp    0
# longitude    0
# latitude     0
# city         0
# state        0
# dtype: int64

# %%
filtered_events_data.longitude.unique()
# Out:
# array([75.939543, 75.935055, 75.889129, ..., 94.126143, 78.235033,
#        75.154661])

# %%
filtered_events_data.latitude.unique()
# Out:
# array([22.76917 , 22.746807, 22.750856, ..., 25.68551 , 24.248452,
#        24.147908])

# %% [markdown]
# ## 6. Data Analysis and visualization

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### 6.1 Distribution of Users(device_id) across States.

# %%
distrtribution_of_users_across_states = pd.DataFrame(filtered_events_data.groupby("state")["device_id"].nunique())
dist_users_across_states = distrtribution_of_users_across_states.reset_index()
dist_users_across_states
# Out:
#              state  device_id
# 0     Chhattisgarh        400
# 1              Goa         76
# 2  JammuandKashmir        236
# 3    MadhyaPradesh       3220
# 4         Nagaland        107
# 5      Uttaranchal        258

# %%
dist_users_across_states.plot("state", "device_id", kind = "bar", grid = True, figsize = (10,6))

# %% [markdown]
# #### 6.2 Distribution of Users across Phone Brands(Consider only 10 Most used Phone Brands).

# %%
phone_brand_device_model_data.head()
# Out:
#              device_id brand models_phone_brand
# 0  1877775838486905855  vivo                Y13
# 1 -3766087376657242966    小米               V183
# 2 -6238937574958215831  OPPO                R7s
# 3  8973197758510677470    三星              A368t
# 4 -2015528097870762664    小米            红米Note2

# %%
distrtribution_of_users_across_phone_brands = pd.DataFrame(phone_brand_device_model_data.groupby("brand")["device_id"].nunique())
dist_users_across_phone_brands = distrtribution_of_users_across_phone_brands.reset_index()
dist_users_across_phone_brands
# Out:
#     brand  device_id
# 0    E人E本          1
# 1      E派         13
# 2     HTC       1272
# 3      LG        360
# 4    LOGO         28
# ..    ...        ...
# 111    飞秒          2
# 112    首云          2
# 113    魅族       5531
# 114    鲜米          2
# 115    黑米         47
#
# [116 rows x 2 columns]

# %%
## Sorting and Filtering top 10 phone brands for visualizing

sorted_dist_users_across_phone_brands = dist_users_across_phone_brands.sort_values("device_id", ascending = False)
top_10_sorted_dist_users_across_phone_brands = sorted_dist_users_across_phone_brands.head(10)
top_10_sorted_dist_users_across_phone_brands
# Out:
#     brand  device_id
# 43     小米      21645
# 14     三星      19211
# 27     华为      15181
# 12   vivo       7596
# 7    OPPO       6717
# 113    魅族       5531
# 103    酷派       3979
# 2     HTC       1272
# 87    联想         982
# 18     乐视        841

# %%
top_10_sorted_dist_users_across_phone_brands.plot("brand","device_id", kind = "bar", grid = True, figsize = (10,6))
# Out:
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 23567 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 31859 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 19977 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26143 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 21326 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20026 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 39749 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 26063 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 37239 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 27966 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 32852 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 24819 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 20048 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:211: RuntimeWarning: Glyph 35270 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 23567 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 31859 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 19977 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26143 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 21326 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20026 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 39749 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 26063 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 37239 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 27966 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 32852 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 24819 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 20048 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\vaithy\Anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:180: RuntimeWarning: Glyph 35270 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# #### 6.3 Distribution of Users across Gender.

# %%
gender_age_train_data.head()
# Out:
#              device_id gender  age age_group
# 0 -8076087639492063270      M   35    M32-38
# 1 -2897161552818060146      M   35    M32-38
# 2 -8260683887967679142      M   35    M32-38
# 3 -4938849341048082022      M   30    M29-31
# 4   245133531816851882      M   30    M29-31

# %%
distribution_of_users_across_gender = pd.DataFrame(gender_age_train_data.groupby("gender")["device_id"].nunique())
dist_users_across_gender = distribution_of_users_across_gender.reset_index()
dist_users_across_gender
# Out:
#   gender  device_id
# 0      F      26741
# 1      M      47904

# %%
dist_users_across_gender.plot("gender", "device_id", kind = "pie", grid = True, figsize = (10,6))
